# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn as nn
from torch.nn import init
import torch.nn.functional as F
from torch.utils.data import DataLoader
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from pytorchtools import EarlyStopping

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### 导入数据

# %%
df2 = pd.read_excel(r"F:\实验室\电网项目\服务器性能数据.xlsx", index_col=0)

# %%
# Draw Plot-----绘图函数
def plot_df(df2, x, y, title="", xlabel='Date_Hour', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df2, x=df2.index, y= df2["主机CPU平均负载"], title='CPU load')

# %% [markdown]
# ### 缺失值填充

# %%
# k近邻法
def knn_mean(ts, n):
    out = np.copy(ts)
    for i, val in enumerate(ts):
        if np.isnan(val):
            n_by_2 = np.ceil(n / 2)
            lower = np.max([0, int(i - n_by_2)])
            upper = np.min([len(ts) + 1, int(i + n_by_2)])
            ts_near = np.concatenate([ts[lower:i], ts[i:upper]])
            out[i] = np.nanmean(ts_near)
    return out
# 使用k-近邻法填补缺失值
df2["主机CPU平均负载"] = knn_mean(df2["主机CPU平均负载"], 24)

# %%
df = df2.copy(deep=True)

# %%
# 滞后阶数
num_hour = 336
data = df["主机CPU平均负载"]
dataframe = pd.DataFrame()
for i in range(num_hour,0,-1):
    dataframe['t-'+str(i)] = data.shift(i)
dataframe['t'] = data.values
dataframe
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2202  4.5833  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500
# 2203  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333
# 2204  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833
# 2205  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833
# 2206  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833  2.4167
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 0        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  2.8333
# 4        NaN  ...     NaN     NaN     NaN     NaN     NaN  2.8333  3.1818
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 2202  2.3333  ...  2.0833  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167
# 2203  2.0833  ...  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833
# 2204  2.0833  ...  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333
# 2205  2.4167  ...  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000
# 2206  2.2500  ...  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000  1.9167
#
#          t-2     t-1       t
# 0        NaN     NaN  2.8333
# 1        NaN  2.8333  3.1818
# 2     2.8333  3.1818  3.0833
# 3     3.1818  3.0833  3.0833
# 4     3.0833  3.0833  2.5000
# ...      ...     ...     ...
# 2202  2.0833  1.8333  2.0000
# 2203  1.8333  2.0000  1.9167
# 2204  2.0000  1.9167  1.7500
# 2205  1.9167  1.7500  2.0000
# 2206  1.7500  2.0000  1.9167
#
# [2207 rows x 337 columns]

# %% [markdown]
# ### 测试集和训练集

# %%
# all_data = dataframe[num_hour:]
# all_data = shuffle(all_data) 
# all_data.to_csv('shuffle.csv')
all_data = pd.read_csv(r"C:\Code\Python\PycharmProjects\数据分析\数据分析\shuffle.csv",index_col=0)
all_data
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 510   3.9167  3.5833  3.5000  3.7500  3.8333  3.5833  3.8182  4.0000  4.4167
# 854   3.7500  3.7500  4.5000  3.9167  3.8182  3.9167  4.3333  3.4167  3.4167
# 1720  3.3333  2.5833  2.7500  2.5000  2.1667  2.0000  2.2500  2.0000  1.9091
# 1564  4.0000  4.1667  5.0833  4.5000  5.9091  7.2500  6.6667  6.7500  4.6667
# 526   3.6667  3.5833  3.2500  3.8182  3.6667  4.1667  3.3636  3.5000  3.9167
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.8333  2.3333  2.1667  2.0833  2.0833  2.5000  2.7500  2.3333  3.0833
# 2055  3.9167  3.8333  3.8333  3.0000  3.0833  3.0833  3.0000  3.0000  3.0000
# 1356  3.5000  3.5000  4.5000  3.9167  4.2500  4.1667  3.8333  3.9091  3.7500
# 2045  4.4167  4.5833  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1190  4.7500  4.3333  4.0833  2.9167  3.1667  3.1667  2.4167  2.2727  2.1667
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 510   3.7500  ...  3.6000  3.5833  3.2500  3.3333  3.7500  3.4167  3.7500
# 854   3.6667  ...  2.3333  2.5833  2.3636  3.5833  3.9167  5.2500  5.6667
# 1720  2.2500  ...  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1564  5.5833  ...  2.5000  2.4167  2.1667  2.5833  2.1667  2.3333  2.9167
# 526   3.8333  ...  3.9167  3.7500  3.7500  4.5000  3.9167  3.8182  3.9167
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.0833  ...  4.4167  4.4167  4.5833  3.4167  2.0833  2.1667  2.0000
# 2055  2.7500  ...  2.5833  2.7500  2.6667  2.5833  2.5833  2.5000  2.5000
# 1356  3.5000  ...  2.3636  2.2500  2.3333  2.7500  2.5000  2.7500  3.6667
# 2045  3.6667  ...  2.3333  2.7500  2.0833  2.6667  3.0833  3.2500  2.8333
# 1190  2.2500  ...  3.5000  3.8333  3.5000  4.0000  6.0833  5.1818  5.3333
#
#          t-2     t-1       t
# 510   3.1667  3.1667  3.4167
# 854   4.2500  5.3333  4.7500
# 1720  3.6667  3.9167  3.8333
# 1564  2.2500  2.3333  2.0833
# 526   4.3333  3.4167  3.4167
# ...      ...     ...     ...
# 1873  2.1667  2.2500  2.5000
# 2055  2.1667  2.7500  2.1667
# 1356  3.6667  3.2500  2.9167
# 2045  2.1667  2.3333  2.5833
# 1190  3.9167  3.4545  4.2500
#
# [1871 rows x 337 columns]

# %%
var1 = int(len(all_data)*0.6)
var2 = int(len(all_data)*0.8)
train_data = all_data[0:var1]
validate_data = all_data[var1:var2]
test_data = all_data[var2:]
# train_data
# test_data
# validate_data

# %%
max_value = max(train_data.max().values)
min_value = min(train_data.min().values)
ch = max_value - min_value

# %% [markdown]
# ### 归一化

# %%
train_data_normalized = scaler.fit_transform(train_data.values.reshape(-1, 1))
train_data_normalized = train_data_normalized.reshape(-1,num_hour+1)
train_data_normalized.shape
# Out:
# (1122, 337)

# %%
validate_data_normalized = scaler.transform(validate_data.values.reshape(-1, 1))
validate_data_normalized = validate_data_normalized.reshape(-1,num_hour+1)
validate_data_normalized.shape
# Out:
# (374, 337)

# %%
test_data_normalized = scaler.transform(test_data.values.reshape(-1, 1))
test_data_normalized = test_data_normalized.reshape(-1,num_hour+1)
test_data_normalized.shape
# Out:
# (375, 337)

# %%
train_X = torch.Tensor(train_data_normalized[:,0:-1].reshape(-1, 14, 24))
train_Y = torch.Tensor(train_data_normalized[:,-1].reshape(-1, 1, 1))
train_X.shape
# Out:
# torch.Size([1122, 14, 24])

# %%
validate_X = torch.Tensor(validate_data_normalized[:,0:-1].reshape(-1, 14, 24))
validate_Y = torch.Tensor(validate_data_normalized[:,-1].reshape(-1, 1, 1))
validate_X.shape
# Out:
# torch.Size([374, 14, 24])

# %%
test_X = torch.Tensor(test_data_normalized[:,0:-1].reshape(-1, 14, 24))
test_Y = torch.Tensor(test_data_normalized[:,-1].reshape(-1, 1, 1))
test_X.shape
# Out:
# torch.Size([375, 14, 24])

# %%
# train_data_temp = torch.utils.data.TensorDataset(train_X, train_Y)
# test_data_temp = torch.utils.data.TensorDataset(test_X, test_Y)
# train_data = DataLoader(train_data_temp, batch_size=256, shuffle=True, num_workers=1)#训练数据
# test_data = DataLoader(test_data_temp, batch_size=256, shuffle=False, num_workers=2)#测试数据

# %%
start = time.time()

# %% [markdown]
# ### 建立LSTM模型

# %%
class lstm(nn.Module):
    def __init__(self,input_size,hidden_size,output_size,num_layer):
        super(lstm,self).__init__()
        self.layer1 = nn.LSTM(input_size,hidden_size,num_layer,batch_first=True)
        self.layer2 = nn.Linear(hidden_size,output_size)
    
    def forward(self,x):
#         x,_ = self.layer1(x)
#         b, s, h = x.size()
#         x = x.reshape(-1,s*h)
#         x = self.layer2(x)
#         x = x.reshape(b, 1, 1)
        x,_ = self.layer1(x)
        x = x[:,[13],:]
        b, s, h = x.size()
        x = x.view(-1,h)
        x = self.layer2(x)
        x = x.view(b, s, -1)
        return x

model = lstm(24, 128, 1, 2)
model
# Out:
# lstm(
#   (layer1): LSTM(24, 128, num_layers=2, batch_first=True)
#   (layer2): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
epoch_n = 1000
# 初始化 early_stopping 对象
# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
patience = 20  

# 关于 EarlyStopping 的代码可先看博客后面的内容
early_stopping = EarlyStopping(patience, verbose=True)

# %%
# 开始训练
ep=[]
losses = []
lr_list = []
for e in range(1, epoch_n+1):
    var_x = Variable(train_X)
    var_y = Variable(train_Y)
    # 前向传播
    out = model(var_x)
    loss = criterion(out, var_y)
    # 反向传播
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if e % 10 == 0: # 每 10 次输出结果
        print('Epoch: {}, Loss: {:.5f}'.format(e, loss.item()))
    ep.append(e)
    losses.append(loss.item())
    
    valid_output = model(validate_X)
    valid_loss = criterion(valid_output, validate_Y)
    
    early_stopping(valid_loss, model)
    
    # 若满足 early stopping 要求
    if early_stopping.early_stop:
        print("Early stopping")
        # 结束模型训练
        break
    
#     break
#     if (e+1)%120 == 0:
#         for p in optimizer.param_groups:
#             p['lr'] *= 0.1
#     lr_list.append(optimizer.state_dict()['param_groups'][0]['lr'])

print('Finished Training')
# Out:
# Validation loss decreased (inf --> 0.358837).  Saving model ...
# Validation loss decreased (0.358837 --> 0.049251).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.049251 --> 0.034322).  Saving model ...
# Validation loss decreased (0.034322 --> 0.018852).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.018852 --> 0.016277).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 10, Loss: 0.02044
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# Validation loss decreased (0.016277 --> 0.015725).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.015725 --> 0.014500).  Saving model ...
# Epoch: 20, Loss: 0.01635
# Validation loss decreased (0.014500 --> 0.013705).  Saving model ...
# Validation loss decreased (0.013705 --> 0.013604).  Saving model ...
# Validation loss decreased (0.013604 --> 0.013588).  Saving model ...
# Validation loss decreased (0.013588 --> 0.013227).  Saving model ...
# Validation loss decreased (0.013227 --> 0.012587).  Saving model ...
# Validation loss decreased (0.012587 --> 0.012320).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.012320 --> 0.011676).  Saving model ...
# Validation loss decreased (0.011676 --> 0.011165).  Saving model ...
# Epoch: 30, Loss: 0.01314
# Validation loss decreased (0.011165 --> 0.010895).  Saving model ...
# Validation loss decreased (0.010895 --> 0.010669).  Saving model ...
# Validation loss decreased (0.010669 --> 0.010419).  Saving model ...
# Validation loss decreased (0.010419 --> 0.010253).  Saving model ...
# Validation loss decreased (0.010253 --> 0.010226).  Saving model ...
# Validation loss decreased (0.010226 --> 0.010083).  Saving model ...
# Validation loss decreased (0.010083 --> 0.009689).  Saving model ...
# Validation loss decreased (0.009689 --> 0.009317).  Saving model ...
# Validation loss decreased (0.009317 --> 0.009073).  Saving model ...
# Validation loss decreased (0.009073 --> 0.008843).  Saving model ...
# Epoch: 40, Loss: 0.01042
# Validation loss decreased (0.008843 --> 0.008707).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.008707 --> 0.008359).  Saving model ...
# Validation loss decreased (0.008359 --> 0.008188).  Saving model ...
# Validation loss decreased (0.008188 --> 0.008146).  Saving model ...
# Validation loss decreased (0.008146 --> 0.008132).  Saving model ...
# Validation loss decreased (0.008132 --> 0.008046).  Saving model ...
# Epoch: 50, Loss: 0.00880
# Validation loss decreased (0.008046 --> 0.007865).  Saving model ...
# Validation loss decreased (0.007865 --> 0.007695).  Saving model ...
# Validation loss decreased (0.007695 --> 0.007583).  Saving model ...
# Validation loss decreased (0.007583 --> 0.007528).  Saving model ...
# Validation loss decreased (0.007528 --> 0.007476).  Saving model ...
# Validation loss decreased (0.007476 --> 0.007350).  Saving model ...
# Validation loss decreased (0.007350 --> 0.007192).  Saving model ...
# Validation loss decreased (0.007192 --> 0.007050).  Saving model ...
# Validation loss decreased (0.007050 --> 0.006930).  Saving model ...
# Validation loss decreased (0.006930 --> 0.006793).  Saving model ...
# Epoch: 60, Loss: 0.00742
# Validation loss decreased (0.006793 --> 0.006620).  Saving model ...
# Validation loss decreased (0.006620 --> 0.006508).  Saving model ...
# Validation loss decreased (0.006508 --> 0.006467).  Saving model ...
# Validation loss decreased (0.006467 --> 0.006415).  Saving model ...
# Validation loss decreased (0.006415 --> 0.006324).  Saving model ...
# Validation loss decreased (0.006324 --> 0.006285).  Saving model ...
# Validation loss decreased (0.006285 --> 0.006277).  Saving model ...
# Validation loss decreased (0.006277 --> 0.006210).  Saving model ...
# Validation loss decreased (0.006210 --> 0.006165).  Saving model ...
# Validation loss decreased (0.006165 --> 0.006149).  Saving model ...
# Epoch: 70, Loss: 0.00654
# Validation loss decreased (0.006149 --> 0.006061).  Saving model ...
# Validation loss decreased (0.006061 --> 0.005951).  Saving model ...
# Validation loss decreased (0.005951 --> 0.005870).  Saving model ...
# Validation loss decreased (0.005870 --> 0.005741).  Saving model ...
# Validation loss decreased (0.005741 --> 0.005612).  Saving model ...
# Validation loss decreased (0.005612 --> 0.005527).  Saving model ...
# Validation loss decreased (0.005527 --> 0.005388).  Saving model ...
# Validation loss decreased (0.005388 --> 0.005303).  Saving model ...
# Validation loss decreased (0.005303 --> 0.005197).  Saving model ...
# Validation loss decreased (0.005197 --> 0.005112).  Saving model ...
# Epoch: 80, Loss: 0.00573
# Validation loss decreased (0.005112 --> 0.005046).  Saving model ...
# Validation loss decreased (0.005046 --> 0.004962).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004962 --> 0.004880).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# Validation loss decreased (0.004880 --> 0.004863).  Saving model ...
# Epoch: 90, Loss: 0.00544
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# Validation loss decreased (0.004863 --> 0.004739).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004739 --> 0.004667).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 100, Loss: 0.00550
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.004667 --> 0.004665).  Saving model ...
# Validation loss decreased (0.004665 --> 0.004582).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.004582 --> 0.004520).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# Validation loss decreased (0.004520 --> 0.004512).  Saving model ...
# Epoch: 110, Loss: 0.00491
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004512 --> 0.004512).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004512 --> 0.004503).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004503 --> 0.004472).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004472 --> 0.004430).  Saving model ...
# Validation loss decreased (0.004430 --> 0.004424).  Saving model ...
# Validation loss decreased (0.004424 --> 0.004397).  Saving model ...
# Epoch: 120, Loss: 0.00471
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004397 --> 0.004332).  Saving model ...
# Validation loss decreased (0.004332 --> 0.004317).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004317 --> 0.004305).  Saving model ...
# Validation loss decreased (0.004305 --> 0.004266).  Saving model ...
# Validation loss decreased (0.004266 --> 0.004247).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004247 --> 0.004224).  Saving model ...
# Validation loss decreased (0.004224 --> 0.004217).  Saving model ...
# Epoch: 130, Loss: 0.00455
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004217 --> 0.004205).  Saving model ...
# Validation loss decreased (0.004205 --> 0.004196).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004196 --> 0.004181).  Saving model ...
# Validation loss decreased (0.004181 --> 0.004166).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004166 --> 0.004145).  Saving model ...
# Validation loss decreased (0.004145 --> 0.004132).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 140, Loss: 0.00442
# Validation loss decreased (0.004132 --> 0.004113).  Saving model ...
# Validation loss decreased (0.004113 --> 0.004105).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004105 --> 0.004095).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004095 --> 0.004083).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004083 --> 0.004069).  Saving model ...
# Validation loss decreased (0.004069 --> 0.004066).  Saving model ...
# Validation loss decreased (0.004066 --> 0.004054).  Saving model ...
# Epoch: 150, Loss: 0.00429
# Validation loss decreased (0.004054 --> 0.004048).  Saving model ...
# Validation loss decreased (0.004048 --> 0.004038).  Saving model ...
# Validation loss decreased (0.004038 --> 0.004031).  Saving model ...
# Validation loss decreased (0.004031 --> 0.004021).  Saving model ...
# Validation loss decreased (0.004021 --> 0.004020).  Saving model ...
# Validation loss decreased (0.004020 --> 0.004014).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Epoch: 160, Loss: 0.01154
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# EarlyStopping counter: 11 out of 20
# EarlyStopping counter: 12 out of 20
# EarlyStopping counter: 13 out of 20
# EarlyStopping counter: 14 out of 20
# Epoch: 170, Loss: 0.00474
# EarlyStopping counter: 15 out of 20
# EarlyStopping counter: 16 out of 20
# EarlyStopping counter: 17 out of 20
# EarlyStopping counter: 18 out of 20
# EarlyStopping counter: 19 out of 20
# EarlyStopping counter: 20 out of 20
# Early stopping
# Finished Training

# %%
end = time.time()

# %%
time = end - start
print(f'运行时长为:{int(time)}s')
# Out:
# 运行时长为:197s

# %%
# plot_df(df, x=range(epoch_n), y= lr_list, title='LOSS')

# %%
plot_df(df, x=ep, y= losses, title='LOSS')

# %%
torch.save(model, 'net.pkl')
model2 = torch.load('net.pkl')
# Out:
# D:\Softwore\python38\lib\site-packages\torch\serialization.py:359: UserWarning: Couldn't retrieve source code for container of type lstm. It won't be checked for correctness upon loading.
#   warnings.warn("Couldn't retrieve source code for container of "

# %% [markdown]
# ### 验证测试集

# %%
def rereal(list_temp, min_value, max_value):
    arr = []
    for dat in list_temp:
        temp = dat*(max_value-min_value) + min_value
        arr.append(temp)
    return arr

# %%
outputs = model2(test_X)
loss = criterion(outputs, test_Y)
loss
# Out:
# tensor(0.0037, grad_fn=<MseLossBackward>)

# %%
num = len(test_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = test_Y.detach().numpy().reshape(num)
# # 二维转一维
# y_pred = []
# for i in range(len(y_pred_temp)):
#     y_pred.append(y_pred_temp[i])
# test_Y = test_Y.reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.0037463309878338928

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# # 未还原归一化
# plt.figure(figsize=(16,5), dpi=100)
# plt.plot(range(num), y_pred, c='red', lw='1')
# plt.plot(range(num), tru_temp, c='blue', lw='1')

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.17922206017243164

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
from numpy import mean
mean(errors_p)
# Out:
# 10.999569933483032

# %% [markdown]
# ### 验证训练集

# %%
outputs = model2(train_X)
loss = criterion(outputs, train_Y)
loss
# Out:
# tensor(0.0050, grad_fn=<MseLossBackward>)

# %%
num = len(train_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = train_Y.detach().numpy().reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.004953128285788439

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.23695446568010847

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
mean(errors_p)
# Out:
# 11.668805128359155
