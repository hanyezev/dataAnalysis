# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn as nn
from torch.nn import init
import torch.nn.functional as F
from torch.utils.data import DataLoader
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from pytorchtools import EarlyStopping

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### 导入数据

# %%
df2 = pd.read_excel(r"F:\实验室\电网项目\服务器性能数据.xlsx", index_col=0)

# %%
# Draw Plot-----绘图函数
def plot_df(df2, x, y, title="", xlabel='Date_Hour', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df2, x=df2.index, y= df2["主机CPU平均负载"], title='CPU load')

# %% [markdown]
# ### 缺失值填充

# %%
# k近邻法
def knn_mean(ts, n):
    out = np.copy(ts)
    for i, val in enumerate(ts):
        if np.isnan(val):
            n_by_2 = np.ceil(n / 2)
            lower = np.max([0, int(i - n_by_2)])
            upper = np.min([len(ts) + 1, int(i + n_by_2)])
            ts_near = np.concatenate([ts[lower:i], ts[i:upper]])
            out[i] = np.nanmean(ts_near)
    return out
# 使用k-近邻法填补缺失值
df2["主机CPU平均负载"] = knn_mean(df2["主机CPU平均负载"], 24)

# %%
df = df2.copy(deep=True)

# %%
# 平滑前,滞后阶数
num_hour = 672
data_1 = df2["主机CPU平均负载"]
dataframe_1 = pd.DataFrame()
for i in range(num_hour-1,0,-1):
    dataframe_1['t-'+str(i)] = data_1.shift(i)
dataframe_1['t'] = data_1.values
for i in range(1,13):
    dataframe_1['t+'+str(i)] = data_1.shift(periods=-i, axis=0)

pd.set_option('display.max_columns', 16)
dataframe_1
# Out:
#        t-671   t-670   t-669   t-668   t-667   t-666   t-665   t-664  ...  \
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 3        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# ...      ...     ...     ...     ...     ...     ...     ...     ...  ...
# 2202  2.8333  2.8333  2.0833  2.0833  2.0833  2.9167  2.8333  2.3333  ...
# 2203  2.8333  2.0833  2.0833  2.0833  2.9167  2.8333  2.3333  2.1667  ...
# 2204  2.0833  2.0833  2.0833  2.9167  2.8333  2.3333  2.1667  2.0833  ...
# 2205  2.0833  2.0833  2.9167  2.8333  2.3333  2.1667  2.0833  2.0833  ...
# 2206  2.0833  2.9167  2.8333  2.3333  2.1667  2.0833  2.0833  2.5000  ...
#
#          t+5     t+6     t+7     t+8     t+9    t+10    t+11    t+12
# 0     2.6667  3.0000  3.0000  2.7500  2.9167  2.9091  2.8333  3.0833
# 1     3.0000  3.0000  2.7500  2.9167  2.9091  2.8333  3.0833  2.6667
# 2     3.0000  2.7500  2.9167  2.9091  2.8333  3.0833  2.6667  2.9167
# 3     2.7500  2.9167  2.9091  2.8333  3.0833  2.6667  2.9167  3.1667
# 4     2.9167  2.9091  2.8333  3.0833  2.6667  2.9167  3.1667  2.8333
# ...      ...     ...     ...     ...     ...     ...     ...     ...
# 2202     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2203     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2204     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2205     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2206     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [2207 rows x 684 columns]

# %% [markdown]
# ### 测试集和训练集

# %%
np.random.seed(2)
all_data = dataframe_1[num_hour-1:-12]
all_data = shuffle(all_data) 
all_data.to_csv('shuffle.csv')
# all_data = pd.read_csv(r"C:\Code\Python\PycharmProjects\数据分析\数据分析\shuffle.csv",index_col=0)
all_data
# Out:
#        t-671   t-670   t-669   t-668   t-667   t-666   t-665   t-664  ...  \
# 1388  2.2727  2.1667  2.1818  2.1000  2.5000  2.5000  2.0833  1.9091  ...
# 1406  3.9167  3.7500  3.7500  3.3333  3.2500  3.0000  3.7273  3.5833  ...
# 814   3.3333  3.3333  3.9167  3.2500  3.1667  3.1818  3.1667  3.5000  ...
# 1436  2.8333  2.5000  2.6667  2.7273  2.7500  2.9167  3.2500  2.1000  ...
# 919   3.6667  4.2500  4.3333  3.4545  3.5833  3.0833  4.2500  4.3333  ...
# ...      ...     ...     ...     ...     ...     ...     ...     ...  ...
# 1137  4.0000  4.0909  3.5833  3.7273  3.9091  4.0833  4.0833  3.8333  ...
# 970   4.1667  4.1667  3.7500  4.4167  4.2500  4.5000  4.4000  4.0833  ...
# 1164  3.7500  3.4167  3.9167  3.5833  3.7273  4.0833  3.8333  3.5833  ...
# 1198  3.6667  4.0833  3.6667  3.6364  3.0833  3.2500  3.0833  3.1667  ...
# 1863  4.5000  5.1667  4.9167  5.0833  4.6667  4.5833  3.8182  4.3333  ...
#
#            t+5       t+6       t+7       t+8       t+9      t+10      t+11  \
# 1388  2.250000  2.166700  1.750000  1.909100  2.083300  2.083300  2.166700
# 1406  2.900020  3.183340  3.258850  3.436157  3.436157  3.436157  3.436157
# 814   2.416700  2.250000  2.545500  2.916700  2.750000  2.750000  3.750000
# 1436  3.103780  3.117073  2.454500  2.750000  2.750000  2.500000  3.000000
# 919   2.666700  2.750000  3.545500  4.166700  5.416700  4.666700  3.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 1137  4.916700  4.900000  4.666700  4.666700  5.416700  4.500000  4.833300
# 970   2.311686  2.397186  2.397186  2.423157  2.339814  2.375529  2.482671
# 1164  4.333300  5.583300  6.250000  4.666700  4.272700  4.250000  4.416700
# 1198  4.833300  4.583300  4.272700  4.333300  4.272700  5.666700  5.416700
# 1863  2.083300  2.166700  2.000000  2.166700  2.250000  2.500000  2.250000
#
#           t+12
# 1388  2.061242
# 1406  3.436157
# 814   3.666700
# 1436  3.166700
# 919   2.727300
# ...        ...
# 1137  4.000000
# 970   2.542200
# 1164  5.181800
# 1198  5.666700
# 1863  2.333300
#
# [1524 rows x 684 columns]

# %%
# dataframe3 = all_data.corr()
# Series1 = dataframe3["t"].sort_values(ascending=False)
# len(Series1[1:85].index)

# %%
# dataframe2 = all_data.loc[:,Series1[1:85].index]
# dataframe2["t"] = all_data["t"]
dataframe2 = all_data

# %%
var1 = int(len(all_data)*0.6)
var2 = int(len(all_data)*0.8)
train_data = all_data.iloc[0:var1]
train_truth = all_data.iloc[0:var1,-12:]
validate_data = all_data.iloc[var1:var2]
validate_truth = all_data.iloc[var1:var2,-12:]
test_data = all_data.iloc[var2:]
test_truth = all_data.iloc[var2:,-12:]
# train_data
# test_data
# validate_data

# %%
# num_hour = 84

# %%
max_value = max(train_data.max().values)
min_value = min(train_data.min().values)
ch = max_value - min_value

# %% [markdown]
# ### 归一化

# %%
train_data_normalized = scaler.fit_transform(train_data.values.reshape(-1, 1))
train_data_normalized = train_data_normalized.reshape(-1,num_hour+12)
train_data_normalized.shape
# Out:
# (914, 684)

# %%
validate_data_normalized = scaler.transform(validate_data.values.reshape(-1, 1))
validate_data_normalized = validate_data_normalized.reshape(-1,num_hour+12)
validate_data_normalized.shape
# Out:
# (305, 684)

# %%
test_data_normalized = scaler.transform(test_data.values.reshape(-1, 1))
test_data_normalized = test_data_normalized.reshape(-1,num_hour+12)
test_data_normalized.shape
# Out:
# (305, 684)

# %%
train_X = torch.Tensor(train_data_normalized[:,0:-12].reshape(-1, 1, num_hour))
train_Y = torch.Tensor(train_data_normalized[:,-12:].reshape(-1, 1, 12))
train_Y.shape
# Out:
# torch.Size([914, 1, 12])

# %%
validate_X = torch.Tensor(validate_data_normalized[:,0:-12].reshape(-1, 1, num_hour))
validate_Y = torch.Tensor(validate_data_normalized[:,-12:].reshape(-1, 1, 12))
validate_X.shape
# Out:
# torch.Size([305, 1, 672])

# %%
test_X = torch.Tensor(test_data_normalized[:,0:-12].reshape(-1, 1, num_hour))
test_Y = torch.Tensor(test_data_normalized[:,-12:].reshape(-1, 1, 12))
test_X.shape
# Out:
# torch.Size([305, 1, 672])

# %%
# train_data_temp = torch.utils.data.TensorDataset(train_X, train_Y)
# test_data_temp = torch.utils.data.TensorDataset(test_X, test_Y)
# train_data = DataLoader(train_data_temp, batch_size=256, shuffle=True, num_workers=1)#训练数据
# test_data = DataLoader(test_data_temp, batch_size=256, shuffle=False, num_workers=2)#测试数据

# %%
start = time.time()

# %% [markdown]
# ### 建立LSTM模型

# %%
class lstm(nn.Module):
    def __init__(self,input_size=16,hidden_size=100,output_size=1,num_layer=2):
        super(lstm,self).__init__()
        self.layer1 = nn.LSTM(input_size,hidden_size,num_layer)
        self.layer2 = nn.Linear(hidden_size,output_size)
    
    def forward(self,x):
        x,_ = self.layer1(x)
        s, b, h = x.size()
        x = x.reshape(s*b,h)
        x = self.layer2(x)
        x = x.reshape(s, b, -1)
        return x

model = lstm(672, 256, 12, 2)
model
# Out:
# lstm(
#   (layer1): LSTM(672, 256, num_layers=2)
#   (layer2): Linear(in_features=256, out_features=12, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
epoch_n = 1000
# 初始化 early_stopping 对象
# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
patience = 20  

# 关于 EarlyStopping 的代码可先看博客后面的内容
early_stopping = EarlyStopping(patience, verbose=True)

# %%
# 开始训练
ep=[]
losses = []
lr_list = []
for e in range(1, epoch_n+1):
    var_x = Variable(train_X)
    var_y = Variable(train_Y)
    # 前向传播
    out = model(var_x)
    loss = criterion(out, var_y)
    # 反向传播
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if e % 10 == 0: # 每 10 次输出结果
        print('Epoch: {}, Loss: {:.5f}'.format(e, loss.item()))
    ep.append(e)
    losses.append(loss.item())
    
    valid_output = model(validate_X)
    valid_loss = criterion(valid_output, validate_Y)
    
    early_stopping(valid_loss, model)
    
    # 若满足 early stopping 要求
    if early_stopping.early_stop:
        print("Early stopping")
        # 结束模型训练
        break
    
#     break
#     if (e+1)%120 == 0:
#         for p in optimizer.param_groups:
#             p['lr'] *= 0.1
#     lr_list.append(optimizer.state_dict()['param_groups'][0]['lr'])

print('Finished Training')
# Out:
# Validation loss decreased (inf --> 2.300697).  Saving model ...
# Validation loss decreased (2.300697 --> 0.937090).  Saving model ...
# Validation loss decreased (0.937090 --> 0.042567).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.042567 --> 0.034862).  Saving model ...
# Validation loss decreased (0.034862 --> 0.032178).  Saving model ...
# Validation loss decreased (0.032178 --> 0.026344).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Epoch: 10, Loss: 0.02781
# EarlyStopping counter: 3 out of 20
# Validation loss decreased (0.026344 --> 0.025647).  Saving model ...
# Validation loss decreased (0.025647 --> 0.025507).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.025507 --> 0.025147).  Saving model ...
# Validation loss decreased (0.025147 --> 0.025120).  Saving model ...
# Validation loss decreased (0.025120 --> 0.024552).  Saving model ...
# Validation loss decreased (0.024552 --> 0.024283).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.024283 --> 0.023603).  Saving model ...
# Epoch: 20, Loss: 0.02486
# Validation loss decreased (0.023603 --> 0.023127).  Saving model ...
# Validation loss decreased (0.023127 --> 0.022633).  Saving model ...
# Validation loss decreased (0.022633 --> 0.022062).  Saving model ...
# Validation loss decreased (0.022062 --> 0.021686).  Saving model ...
# Validation loss decreased (0.021686 --> 0.020905).  Saving model ...
# Validation loss decreased (0.020905 --> 0.020391).  Saving model ...
# Validation loss decreased (0.020391 --> 0.019579).  Saving model ...
# Validation loss decreased (0.019579 --> 0.018827).  Saving model ...
# Validation loss decreased (0.018827 --> 0.017947).  Saving model ...
# Validation loss decreased (0.017947 --> 0.017166).  Saving model ...
# Epoch: 30, Loss: 0.01811
# Validation loss decreased (0.017166 --> 0.016419).  Saving model ...
# Validation loss decreased (0.016419 --> 0.015800).  Saving model ...
# Validation loss decreased (0.015800 --> 0.015111).  Saving model ...
# Validation loss decreased (0.015111 --> 0.014665).  Saving model ...
# Validation loss decreased (0.014665 --> 0.014012).  Saving model ...
# Validation loss decreased (0.014012 --> 0.013557).  Saving model ...
# Validation loss decreased (0.013557 --> 0.013333).  Saving model ...
# Validation loss decreased (0.013333 --> 0.012776).  Saving model ...
# Validation loss decreased (0.012776 --> 0.012486).  Saving model ...
# Validation loss decreased (0.012486 --> 0.012439).  Saving model ...
# Epoch: 40, Loss: 0.01384
# Validation loss decreased (0.012439 --> 0.012129).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.012129 --> 0.011925).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.011925 --> 0.011770).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# Validation loss decreased (0.011770 --> 0.011218).  Saving model ...
# Validation loss decreased (0.011218 --> 0.010986).  Saving model ...
# Epoch: 50, Loss: 0.01154
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# Validation loss decreased (0.010986 --> 0.010612).  Saving model ...
# Validation loss decreased (0.010612 --> 0.010577).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.010577 --> 0.010454).  Saving model ...
# Validation loss decreased (0.010454 --> 0.010262).  Saving model ...
# Validation loss decreased (0.010262 --> 0.010229).  Saving model ...
# Validation loss decreased (0.010229 --> 0.010197).  Saving model ...
# Epoch: 60, Loss: 0.01038
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.010197 --> 0.009942).  Saving model ...
# Validation loss decreased (0.009942 --> 0.009865).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.009865 --> 0.009858).  Saving model ...
# Validation loss decreased (0.009858 --> 0.009623).  Saving model ...
# Validation loss decreased (0.009623 --> 0.009532).  Saving model ...
# Validation loss decreased (0.009532 --> 0.009513).  Saving model ...
# Validation loss decreased (0.009513 --> 0.009482).  Saving model ...
# Epoch: 70, Loss: 0.00939
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.009482 --> 0.009480).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.009480 --> 0.009420).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.009420 --> 0.009309).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.009309 --> 0.009133).  Saving model ...
# Validation loss decreased (0.009133 --> 0.009091).  Saving model ...
# Validation loss decreased (0.009091 --> 0.008950).  Saving model ...
# Epoch: 80, Loss: 0.00873
# Validation loss decreased (0.008950 --> 0.008915).  Saving model ...
# Validation loss decreased (0.008915 --> 0.008834).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# Validation loss decreased (0.008834 --> 0.008513).  Saving model ...
# Epoch: 90, Loss: 0.00825
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# Validation loss decreased (0.008513 --> 0.008327).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Epoch: 100, Loss: 0.00806
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.008327 --> 0.008260).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.008260 --> 0.008201).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.008201 --> 0.008050).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.008050 --> 0.008016).  Saving model ...
# Epoch: 110, Loss: 0.00773
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.008016 --> 0.007910).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007910 --> 0.007841).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007841 --> 0.007768).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 120, Loss: 0.00752
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007768 --> 0.007708).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007708 --> 0.007675).  Saving model ...
# Validation loss decreased (0.007675 --> 0.007615).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007615 --> 0.007594).  Saving model ...
# Validation loss decreased (0.007594 --> 0.007536).  Saving model ...
# Epoch: 130, Loss: 0.00718
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.007536 --> 0.007505).  Saving model ...
# Validation loss decreased (0.007505 --> 0.007467).  Saving model ...
# Validation loss decreased (0.007467 --> 0.007444).  Saving model ...
# Validation loss decreased (0.007444 --> 0.007438).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.007438 --> 0.007416).  Saving model ...
# Validation loss decreased (0.007416 --> 0.007400).  Saving model ...
# Validation loss decreased (0.007400 --> 0.007345).  Saving model ...
# Epoch: 140, Loss: 0.00696
# Validation loss decreased (0.007345 --> 0.007321).  Saving model ...
# Validation loss decreased (0.007321 --> 0.007296).  Saving model ...
# Validation loss decreased (0.007296 --> 0.007276).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.007276 --> 0.007262).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# Epoch: 150, Loss: 0.00875
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# EarlyStopping counter: 11 out of 20
# EarlyStopping counter: 12 out of 20
# EarlyStopping counter: 13 out of 20
# EarlyStopping counter: 14 out of 20
# EarlyStopping counter: 15 out of 20
# Epoch: 160, Loss: 0.00790
# EarlyStopping counter: 16 out of 20
# EarlyStopping counter: 17 out of 20
# EarlyStopping counter: 18 out of 20
# Validation loss decreased (0.007262 --> 0.007244).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.007244 --> 0.007120).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Epoch: 170, Loss: 0.00688
# Validation loss decreased (0.007120 --> 0.006966).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.006966 --> 0.006962).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006962 --> 0.006844).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006844 --> 0.006831).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 180, Loss: 0.00644
# Validation loss decreased (0.006831 --> 0.006733).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006733 --> 0.006668).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006668 --> 0.006617).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006617 --> 0.006563).  Saving model ...
# Epoch: 190, Loss: 0.00605
# Validation loss decreased (0.006563 --> 0.006551).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.006551 --> 0.006519).  Saving model ...
# Validation loss decreased (0.006519 --> 0.006469).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.006469 --> 0.006420).  Saving model ...
# Validation loss decreased (0.006420 --> 0.006393).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.006393 --> 0.006388).  Saving model ...
# Epoch: 200, Loss: 0.00583
# Validation loss decreased (0.006388 --> 0.006360).  Saving model ...
# Validation loss decreased (0.006360 --> 0.006325).  Saving model ...
# Validation loss decreased (0.006325 --> 0.006312).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.006312 --> 0.006304).  Saving model ...
# Validation loss decreased (0.006304 --> 0.006288).  Saving model ...
# Validation loss decreased (0.006288 --> 0.006260).  Saving model ...
# Validation loss decreased (0.006260 --> 0.006237).  Saving model ...
# Validation loss decreased (0.006237 --> 0.006216).  Saving model ...
# Validation loss decreased (0.006216 --> 0.006200).  Saving model ...
# Epoch: 210, Loss: 0.00558
# Validation loss decreased (0.006200 --> 0.006189).  Saving model ...
# Validation loss decreased (0.006189 --> 0.006181).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# Epoch: 220, Loss: 0.01190
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# EarlyStopping counter: 11 out of 20
# EarlyStopping counter: 12 out of 20
# EarlyStopping counter: 13 out of 20
# EarlyStopping counter: 14 out of 20
# EarlyStopping counter: 15 out of 20
# EarlyStopping counter: 16 out of 20
# EarlyStopping counter: 17 out of 20
# EarlyStopping counter: 18 out of 20
# Epoch: 230, Loss: 0.00579
# EarlyStopping counter: 19 out of 20
# EarlyStopping counter: 20 out of 20
# Early stopping
# Finished Training

# %%
end = time.time()|
# Out:
#   File "<ipython-input-29-aa9a8bdc02c6>", line 1
#     end = time.time()|
#                       ^
# SyntaxError: invalid syntax

# %%
time = end - start
print(f'运行时长为:{int(time)}s')
# Out:
# 运行时长为:704s

# %%
# plot_df(df, x=range(epoch_n), y= lr_list, title='LOSS')

# %%
plot_df(df, x=ep, y= losses, title='LOSS')

# %%
torch.save(model, 'net.pkl')
model2 = torch.load('net.pkl')
# Out:
# D:\Softwore\python38\lib\site-packages\torch\serialization.py:359: UserWarning: Couldn't retrieve source code for container of type lstm. It won't be checked for correctness upon loading.
#   warnings.warn("Couldn't retrieve source code for container of "

# %% [markdown]
# ### 验证测试集

# %%
# def rereal(list_temp, min_value, max_value):
#     arr = []
#     for dat in list_temp:
#         temp = dat*(max_value-min_value) + min_value
#         arr.append(temp)
#     return arr

# %%
outputs = model2(test_X)
loss = criterion(outputs, test_Y)
loss
# Out:
# tensor(0.0067, grad_fn=<MseLossBackward>)

# %%
# num = len(test_Y)

# %%
def com_test(arr1,arr2):
    MSEs = []
    errors = []
    MAPEs = []
    num_temp = len(arr1)
    
    for i in range(num_temp):
        error = abs(arr1[i] - arr2[i])
        errors.append(error)
        MSEs.append(error**2)
        MAPEs.append((error/arr2[i])*100)
    
    MSE = np.mean(MSEs)
    MAPE = np.mean(MAPEs)
    
    return MSE, MAPE, MAPEs, errors

def mape(y_true, y_pred):
    """
    参数:
    y_true -- 测试集目标真实值
    y_pred -- 测试集目标预测值
    
    返回:
    mape -- MAPE 评价指标
    """
    y_true = y_true.reshape(-1).detach().numpy()
    y_pred = y_pred.reshape(-1).detach().numpy()
    n = len(y_true)
    mape = sum(np.abs((y_true - y_pred)/y_true))/n*100
    return mape

# %%
predict = outputs*(max_value-min_value) + min_value
truth =  torch.Tensor(test_truth.values.reshape(-1, 1, 12))

# %%
print(f"测试集整体MSE: {criterion(predict, truth)}")
# Out:
# 测试集整体MSE: 0.3200411796569824

# %%
print(f"测试集整体MAPE: {mape(truth, predict)}")
# Out:
# 测试集整体MAPE: 13.464772914745193

# %%
# # 未还原归一化
# plt.figure(figsize=(16,5), dpi=100)
# plt.plot(range(num), y_pred, c='red', lw='1')
# plt.plot(range(num), tru_temp, c='blue', lw='1')

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求测试集真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.23837988984020805

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
from numpy import mean
mean(errors_p)
# Out:
# 11.940034591032633

# %% [markdown]
# ### 验证训练集

# %%
outputs = model2(train_X)
loss = criterion(outputs, train_Y)
loss
# Out:
# tensor(0.0028, grad_fn=<MseLossBackward>)

# %%
num = len(train_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = train_Y.detach().numpy().reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.0028044905159582936

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求训练集真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.13416501870703693

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
mean(errors_p)
# Out:
# 9.328974132857805
