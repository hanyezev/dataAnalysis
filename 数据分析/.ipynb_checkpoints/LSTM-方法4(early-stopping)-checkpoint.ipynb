# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn as nn
from torch.nn import init
import torch.nn.functional as F
from torch.utils.data import DataLoader
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from pytorchtools import EarlyStopping

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### 导入数据

# %%
df2 = pd.read_excel(r"F:\实验室\电网项目\服务器性能数据.xlsx", index_col=0)

# %%
# Draw Plot-----绘图函数
def plot_df(df2, x, y, title="", xlabel='Date_Hour', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df2, x=df2.index, y= df2["主机CPU平均负载"], title='CPU load')

# %% [markdown]
# ### 缺失值填充

# %%
# k近邻法
def knn_mean(ts, n):
    out = np.copy(ts)
    for i, val in enumerate(ts):
        if np.isnan(val):
            n_by_2 = np.ceil(n / 2)
            lower = np.max([0, int(i - n_by_2)])
            upper = np.min([len(ts) + 1, int(i + n_by_2)])
            ts_near = np.concatenate([ts[lower:i], ts[i:upper]])
            out[i] = np.nanmean(ts_near)
    return out
# 使用k-近邻法填补缺失值
df2["主机CPU平均负载"] = knn_mean(df2["主机CPU平均负载"], 24)

# %%
df = df2.copy(deep=True)

# %%
# 滞后阶数
num_hour = 336
data = df["主机CPU平均负载"]
dataframe = pd.DataFrame()
for i in range(num_hour,0,-1):
    dataframe['t-'+str(i)] = data.shift(i)
dataframe['t'] = data.values
dataframe
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2202  4.5833  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500
# 2203  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333
# 2204  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833
# 2205  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833
# 2206  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833  2.4167
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 0        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  2.8333
# 4        NaN  ...     NaN     NaN     NaN     NaN     NaN  2.8333  3.1818
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 2202  2.3333  ...  2.0833  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167
# 2203  2.0833  ...  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833
# 2204  2.0833  ...  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333
# 2205  2.4167  ...  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000
# 2206  2.2500  ...  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000  1.9167
#
#          t-2     t-1       t
# 0        NaN     NaN  2.8333
# 1        NaN  2.8333  3.1818
# 2     2.8333  3.1818  3.0833
# 3     3.1818  3.0833  3.0833
# 4     3.0833  3.0833  2.5000
# ...      ...     ...     ...
# 2202  2.0833  1.8333  2.0000
# 2203  1.8333  2.0000  1.9167
# 2204  2.0000  1.9167  1.7500
# 2205  1.9167  1.7500  2.0000
# 2206  1.7500  2.0000  1.9167
#
# [2207 rows x 337 columns]

# %% [markdown]
# ### 测试集和训练集

# %%
# all_data = dataframe[num_hour:]
# all_data = shuffle(all_data) 
# all_data.to_csv('shuffle.csv')
all_data = pd.read_csv(r"C:\Code\Python\PycharmProjects\数据分析\数据分析\shuffle.csv",index_col=0)
all_data
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 510   3.9167  3.5833  3.5000  3.7500  3.8333  3.5833  3.8182  4.0000  4.4167
# 854   3.7500  3.7500  4.5000  3.9167  3.8182  3.9167  4.3333  3.4167  3.4167
# 1720  3.3333  2.5833  2.7500  2.5000  2.1667  2.0000  2.2500  2.0000  1.9091
# 1564  4.0000  4.1667  5.0833  4.5000  5.9091  7.2500  6.6667  6.7500  4.6667
# 526   3.6667  3.5833  3.2500  3.8182  3.6667  4.1667  3.3636  3.5000  3.9167
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.8333  2.3333  2.1667  2.0833  2.0833  2.5000  2.7500  2.3333  3.0833
# 2055  3.9167  3.8333  3.8333  3.0000  3.0833  3.0833  3.0000  3.0000  3.0000
# 1356  3.5000  3.5000  4.5000  3.9167  4.2500  4.1667  3.8333  3.9091  3.7500
# 2045  4.4167  4.5833  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1190  4.7500  4.3333  4.0833  2.9167  3.1667  3.1667  2.4167  2.2727  2.1667
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 510   3.7500  ...  3.6000  3.5833  3.2500  3.3333  3.7500  3.4167  3.7500
# 854   3.6667  ...  2.3333  2.5833  2.3636  3.5833  3.9167  5.2500  5.6667
# 1720  2.2500  ...  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1564  5.5833  ...  2.5000  2.4167  2.1667  2.5833  2.1667  2.3333  2.9167
# 526   3.8333  ...  3.9167  3.7500  3.7500  4.5000  3.9167  3.8182  3.9167
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.0833  ...  4.4167  4.4167  4.5833  3.4167  2.0833  2.1667  2.0000
# 2055  2.7500  ...  2.5833  2.7500  2.6667  2.5833  2.5833  2.5000  2.5000
# 1356  3.5000  ...  2.3636  2.2500  2.3333  2.7500  2.5000  2.7500  3.6667
# 2045  3.6667  ...  2.3333  2.7500  2.0833  2.6667  3.0833  3.2500  2.8333
# 1190  2.2500  ...  3.5000  3.8333  3.5000  4.0000  6.0833  5.1818  5.3333
#
#          t-2     t-1       t
# 510   3.1667  3.1667  3.4167
# 854   4.2500  5.3333  4.7500
# 1720  3.6667  3.9167  3.8333
# 1564  2.2500  2.3333  2.0833
# 526   4.3333  3.4167  3.4167
# ...      ...     ...     ...
# 1873  2.1667  2.2500  2.5000
# 2055  2.1667  2.7500  2.1667
# 1356  3.6667  3.2500  2.9167
# 2045  2.1667  2.3333  2.5833
# 1190  3.9167  3.4545  4.2500
#
# [1871 rows x 337 columns]

# %%
var1 = int(len(all_data)*0.6)
var2 = int(len(all_data)*0.8)
train_data = all_data[0:var1]
validate_data = all_data[var1:var2]
test_data = all_data[var2:]
# train_data
# test_data
# validate_data

# %%
max_value = max(train_data.max().values)
min_value = min(train_data.min().values)
ch = max_value - min_value

# %% [markdown]
# ### 归一化

# %%
train_data_normalized = scaler.fit_transform(train_data.values.reshape(-1, 1))
train_data_normalized = train_data_normalized.reshape(-1,num_hour+1)
train_data_normalized.shape
# Out:
# (1122, 337)

# %%
validate_data_normalized = scaler.transform(validate_data.values.reshape(-1, 1))
validate_data_normalized = validate_data_normalized.reshape(-1,num_hour+1)
validate_data_normalized.shape
# Out:
# (374, 337)

# %%
test_data_normalized = scaler.transform(test_data.values.reshape(-1, 1))
test_data_normalized = test_data_normalized.reshape(-1,num_hour+1)
test_data_normalized.shape
# Out:
# (375, 337)

# %%
train_X = torch.Tensor(train_data_normalized[:,0:-1].reshape(-1, 14, 24))
train_Y = torch.Tensor(train_data_normalized[:,-1].reshape(-1, 1, 1))
train_Y.shape
# Out:
# torch.Size([1122, 1, 1])

# %%
validate_X = torch.Tensor(validate_data_normalized[:,0:-1].reshape(-1, 14, 24))
validate_Y = torch.Tensor(validate_data_normalized[:,-1].reshape(-1, 1, 1))
validate_X.shape
# Out:
# torch.Size([374, 14, 24])

# %%
test_X = torch.Tensor(test_data_normalized[:,0:-1].reshape(-1, 14, 24))
test_Y = torch.Tensor(test_data_normalized[:,-1].reshape(-1, 1, 1))
test_X.shape
# Out:
# torch.Size([375, 14, 24])

# %%
# train_data_temp = torch.utils.data.TensorDataset(train_X, train_Y)
# test_data_temp = torch.utils.data.TensorDataset(test_X, test_Y)
# train_data = DataLoader(train_data_temp, batch_size=256, shuffle=True, num_workers=1)#训练数据
# test_data = DataLoader(test_data_temp, batch_size=256, shuffle=False, num_workers=2)#测试数据

# %%
start = time.time()

# %% [markdown]
# ### 建立LSTM模型

# %%
class lstm(nn.Module):
    def __init__(self,input_size=16,hidden_size=100,output_size=1,num_layer=2):
        super(lstm,self).__init__()
        self.layer1 = nn.LSTM(input_size,hidden_size,num_layer,batch_first=True)
        self.layer2 = nn.Linear(hidden_size*14,output_size)
    
    def forward(self,x):
        x,_ = self.layer1(x)
#         x = x[:,[13],:]
        b, s, h = x.size()
        x = x.reshape(-1,s*h)
        x = self.layer2(x)
        x = x.reshape(b, 1, 1)
        return x

model = lstm(24, 128, 1, 2)
model
# Out:
# lstm(
#   (layer1): LSTM(24, 128, num_layers=2, batch_first=True)
#   (layer2): Linear(in_features=1792, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
epoch_n = 1000
# 初始化 early_stopping 对象
# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
patience = 50  

# 关于 EarlyStopping 的代码可先看博客后面的内容
early_stopping = EarlyStopping(patience, verbose=True)

# %%
# 开始训练
ep=[]
losses = []
lr_list = []
for e in range(1, epoch_n+1):
    var_x = Variable(train_X)
    var_y = Variable(train_Y)
    # 前向传播
    out = model(var_x)
    loss = criterion(out, var_y)
    # 反向传播
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if e % 10 == 0: # 每 10 次输出结果
        print('Epoch: {}, Loss: {:.5f}'.format(e, loss.item()))
    ep.append(e)
    losses.append(loss.item())
    
    valid_output = model(validate_X)
    valid_loss = criterion(valid_output, validate_Y)
    
    early_stopping(valid_loss, model)
    
    # 若满足 early stopping 要求
    if early_stopping.early_stop:
        print("Early stopping")
        # 结束模型训练
        break
    
#     break
#     if (e+1)%120 == 0:
#         for p in optimizer.param_groups:
#             p['lr'] *= 0.1
#     lr_list.append(optimizer.state_dict()['param_groups'][0]['lr'])

print('Finished Training')
# Out:
# Validation loss decreased (inf --> 0.663099).  Saving model ...
# Validation loss decreased (0.663099 --> 0.346278).  Saving model ...
# Validation loss decreased (0.346278 --> 0.130213).  Saving model ...
# Validation loss decreased (0.130213 --> 0.063919).  Saving model ...
# Validation loss decreased (0.063919 --> 0.035047).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.035047 --> 0.023224).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Epoch: 10, Loss: 0.03626
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.023224 --> 0.019677).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.019677 --> 0.019650).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Epoch: 20, Loss: 0.03397
# EarlyStopping counter: 4 out of 50
# Validation loss decreased (0.019650 --> 0.018686).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.018686 --> 0.017398).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Epoch: 30, Loss: 0.01976
# Validation loss decreased (0.017398 --> 0.016514).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.016514 --> 0.016191).  Saving model ...
# Validation loss decreased (0.016191 --> 0.015634).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.015634 --> 0.015487).  Saving model ...
# Epoch: 40, Loss: 0.01687
# Validation loss decreased (0.015487 --> 0.014671).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.014671 --> 0.014179).  Saving model ...
# Validation loss decreased (0.014179 --> 0.014124).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.014124 --> 0.013671).  Saving model ...
# Epoch: 50, Loss: 0.01529
# Validation loss decreased (0.013671 --> 0.013417).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.013417 --> 0.013186).  Saving model ...
# Validation loss decreased (0.013186 --> 0.013006).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.013006 --> 0.012707).  Saving model ...
# Validation loss decreased (0.012707 --> 0.012489).  Saving model ...
# Epoch: 60, Loss: 0.01411
# Validation loss decreased (0.012489 --> 0.012466).  Saving model ...
# Validation loss decreased (0.012466 --> 0.012374).  Saving model ...
# Validation loss decreased (0.012374 --> 0.012179).  Saving model ...
# Validation loss decreased (0.012179 --> 0.012098).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.012098 --> 0.012088).  Saving model ...
# Validation loss decreased (0.012088 --> 0.011830).  Saving model ...
# Validation loss decreased (0.011830 --> 0.011598).  Saving model ...
# Validation loss decreased (0.011598 --> 0.011500).  Saving model ...
# Validation loss decreased (0.011500 --> 0.011399).  Saving model ...
# Epoch: 70, Loss: 0.01298
# Validation loss decreased (0.011399 --> 0.011243).  Saving model ...
# Validation loss decreased (0.011243 --> 0.011158).  Saving model ...
# Validation loss decreased (0.011158 --> 0.011135).  Saving model ...
# Validation loss decreased (0.011135 --> 0.011012).  Saving model ...
# Validation loss decreased (0.011012 --> 0.010807).  Saving model ...
# Validation loss decreased (0.010807 --> 0.010671).  Saving model ...
# Validation loss decreased (0.010671 --> 0.010583).  Saving model ...
# Validation loss decreased (0.010583 --> 0.010459).  Saving model ...
# Validation loss decreased (0.010459 --> 0.010368).  Saving model ...
# Validation loss decreased (0.010368 --> 0.010323).  Saving model ...
# Epoch: 80, Loss: 0.01170
# Validation loss decreased (0.010323 --> 0.010209).  Saving model ...
# Validation loss decreased (0.010209 --> 0.010059).  Saving model ...
# Validation loss decreased (0.010059 --> 0.009969).  Saving model ...
# Validation loss decreased (0.009969 --> 0.009877).  Saving model ...
# Validation loss decreased (0.009877 --> 0.009780).  Saving model ...
# Validation loss decreased (0.009780 --> 0.009726).  Saving model ...
# Validation loss decreased (0.009726 --> 0.009631).  Saving model ...
# Validation loss decreased (0.009631 --> 0.009512).  Saving model ...
# Validation loss decreased (0.009512 --> 0.009434).  Saving model ...
# Validation loss decreased (0.009434 --> 0.009339).  Saving model ...
# Epoch: 90, Loss: 0.01061
# Validation loss decreased (0.009339 --> 0.009260).  Saving model ...
# Validation loss decreased (0.009260 --> 0.009185).  Saving model ...
# Validation loss decreased (0.009185 --> 0.009073).  Saving model ...
# Validation loss decreased (0.009073 --> 0.008992).  Saving model ...
# Validation loss decreased (0.008992 --> 0.008895).  Saving model ...
# Validation loss decreased (0.008895 --> 0.008809).  Saving model ...
# Validation loss decreased (0.008809 --> 0.008720).  Saving model ...
# Validation loss decreased (0.008720 --> 0.008617).  Saving model ...
# Validation loss decreased (0.008617 --> 0.008530).  Saving model ...
# Validation loss decreased (0.008530 --> 0.008425).  Saving model ...
# Epoch: 100, Loss: 0.00964
# Validation loss decreased (0.008425 --> 0.008336).  Saving model ...
# Validation loss decreased (0.008336 --> 0.008229).  Saving model ...
# Validation loss decreased (0.008229 --> 0.008138).  Saving model ...
# Validation loss decreased (0.008138 --> 0.008031).  Saving model ...
# Validation loss decreased (0.008031 --> 0.007935).  Saving model ...
# Validation loss decreased (0.007935 --> 0.007830).  Saving model ...
# Validation loss decreased (0.007830 --> 0.007736).  Saving model ...
# Validation loss decreased (0.007736 --> 0.007630).  Saving model ...
# Validation loss decreased (0.007630 --> 0.007534).  Saving model ...
# Validation loss decreased (0.007534 --> 0.007433).  Saving model ...
# Epoch: 110, Loss: 0.00863
# Validation loss decreased (0.007433 --> 0.007339).  Saving model ...
# Validation loss decreased (0.007339 --> 0.007238).  Saving model ...
# Validation loss decreased (0.007238 --> 0.007144).  Saving model ...
# Validation loss decreased (0.007144 --> 0.007052).  Saving model ...
# Validation loss decreased (0.007052 --> 0.006958).  Saving model ...
# Validation loss decreased (0.006958 --> 0.006868).  Saving model ...
# Validation loss decreased (0.006868 --> 0.006778).  Saving model ...
# Validation loss decreased (0.006778 --> 0.006693).  Saving model ...
# Validation loss decreased (0.006693 --> 0.006608).  Saving model ...
# Validation loss decreased (0.006608 --> 0.006525).  Saving model ...
# Epoch: 120, Loss: 0.00770
# Validation loss decreased (0.006525 --> 0.006448).  Saving model ...
# Validation loss decreased (0.006448 --> 0.006371).  Saving model ...
# Validation loss decreased (0.006371 --> 0.006297).  Saving model ...
# Validation loss decreased (0.006297 --> 0.006228).  Saving model ...
# Validation loss decreased (0.006228 --> 0.006161).  Saving model ...
# Validation loss decreased (0.006161 --> 0.006095).  Saving model ...
# Validation loss decreased (0.006095 --> 0.006034).  Saving model ...
# Validation loss decreased (0.006034 --> 0.005978).  Saving model ...
# Validation loss decreased (0.005978 --> 0.005922).  Saving model ...
# Validation loss decreased (0.005922 --> 0.005869).  Saving model ...
# Epoch: 130, Loss: 0.00693
# Validation loss decreased (0.005869 --> 0.005818).  Saving model ...
# Validation loss decreased (0.005818 --> 0.005769).  Saving model ...
# Validation loss decreased (0.005769 --> 0.005722).  Saving model ...
# Validation loss decreased (0.005722 --> 0.005677).  Saving model ...
# Validation loss decreased (0.005677 --> 0.005634).  Saving model ...
# Validation loss decreased (0.005634 --> 0.005590).  Saving model ...
# Validation loss decreased (0.005590 --> 0.005559).  Saving model ...
# Validation loss decreased (0.005559 --> 0.005534).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Epoch: 140, Loss: 0.00706
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# Validation loss decreased (0.005534 --> 0.005216).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# Epoch: 150, Loss: 0.00649
# EarlyStopping counter: 7 out of 50
# Validation loss decreased (0.005216 --> 0.005188).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.005188 --> 0.005157).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# Epoch: 160, Loss: 0.00625
# Validation loss decreased (0.005157 --> 0.005111).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.005111 --> 0.004990).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004990 --> 0.004939).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004939 --> 0.004892).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# Validation loss decreased (0.004892 --> 0.004808).  Saving model ...
# Epoch: 170, Loss: 0.00554
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004808 --> 0.004768).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004768 --> 0.004720).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004720 --> 0.004703).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004703 --> 0.004668).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004668 --> 0.004625).  Saving model ...
# Epoch: 180, Loss: 0.00519
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004625 --> 0.004561).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004561 --> 0.004503).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004503 --> 0.004439).  Saving model ...
# Validation loss decreased (0.004439 --> 0.004430).  Saving model ...
# Validation loss decreased (0.004430 --> 0.004401).  Saving model ...
# Validation loss decreased (0.004401 --> 0.004395).  Saving model ...
# Validation loss decreased (0.004395 --> 0.004354).  Saving model ...
# Epoch: 190, Loss: 0.00497
# Validation loss decreased (0.004354 --> 0.004339).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004339 --> 0.004315).  Saving model ...
# Validation loss decreased (0.004315 --> 0.004303).  Saving model ...
# Validation loss decreased (0.004303 --> 0.004282).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.004282 --> 0.004256).  Saving model ...
# Validation loss decreased (0.004256 --> 0.004248).  Saving model ...
# Validation loss decreased (0.004248 --> 0.004234).  Saving model ...
# Validation loss decreased (0.004234 --> 0.004220).  Saving model ...
# Epoch: 200, Loss: 0.00478
# Validation loss decreased (0.004220 --> 0.004199).  Saving model ...
# Validation loss decreased (0.004199 --> 0.004180).  Saving model ...
# Validation loss decreased (0.004180 --> 0.004178).  Saving model ...
# Validation loss decreased (0.004178 --> 0.004152).  Saving model ...
# Validation loss decreased (0.004152 --> 0.004142).  Saving model ...
# Validation loss decreased (0.004142 --> 0.004136).  Saving model ...
# Validation loss decreased (0.004136 --> 0.004123).  Saving model ...
# Validation loss decreased (0.004123 --> 0.004115).  Saving model ...
# Validation loss decreased (0.004115 --> 0.004107).  Saving model ...
# Validation loss decreased (0.004107 --> 0.004103).  Saving model ...
# Epoch: 210, Loss: 0.00462
# Validation loss decreased (0.004103 --> 0.004093).  Saving model ...
# Validation loss decreased (0.004093 --> 0.004085).  Saving model ...
# Validation loss decreased (0.004085 --> 0.004083).  Saving model ...
# Validation loss decreased (0.004083 --> 0.004070).  Saving model ...
# Validation loss decreased (0.004070 --> 0.004061).  Saving model ...
# Validation loss decreased (0.004061 --> 0.004056).  Saving model ...
# Validation loss decreased (0.004056 --> 0.004042).  Saving model ...
# Validation loss decreased (0.004042 --> 0.004032).  Saving model ...
# Validation loss decreased (0.004032 --> 0.004025).  Saving model ...
# Validation loss decreased (0.004025 --> 0.004013).  Saving model ...
# Epoch: 220, Loss: 0.00449
# Validation loss decreased (0.004013 --> 0.004004).  Saving model ...
# Validation loss decreased (0.004004 --> 0.003998).  Saving model ...
# Validation loss decreased (0.003998 --> 0.003989).  Saving model ...
# Validation loss decreased (0.003989 --> 0.003982).  Saving model ...
# Validation loss decreased (0.003982 --> 0.003976).  Saving model ...
# Validation loss decreased (0.003976 --> 0.003969).  Saving model ...
# Validation loss decreased (0.003969 --> 0.003962).  Saving model ...
# Validation loss decreased (0.003962 --> 0.003955).  Saving model ...
# Validation loss decreased (0.003955 --> 0.003949).  Saving model ...
# Validation loss decreased (0.003949 --> 0.003941).  Saving model ...
# Epoch: 230, Loss: 0.00439
# Validation loss decreased (0.003941 --> 0.003933).  Saving model ...
# Validation loss decreased (0.003933 --> 0.003925).  Saving model ...
# Validation loss decreased (0.003925 --> 0.003918).  Saving model ...
# Validation loss decreased (0.003918 --> 0.003911).  Saving model ...
# Validation loss decreased (0.003911 --> 0.003903).  Saving model ...
# Validation loss decreased (0.003903 --> 0.003896).  Saving model ...
# Validation loss decreased (0.003896 --> 0.003889).  Saving model ...
# Validation loss decreased (0.003889 --> 0.003883).  Saving model ...
# Validation loss decreased (0.003883 --> 0.003878).  Saving model ...
# Validation loss decreased (0.003878 --> 0.003871).  Saving model ...
# Epoch: 240, Loss: 0.00430
# Validation loss decreased (0.003871 --> 0.003866).  Saving model ...
# Validation loss decreased (0.003866 --> 0.003860).  Saving model ...
# Validation loss decreased (0.003860 --> 0.003855).  Saving model ...
# Validation loss decreased (0.003855 --> 0.003848).  Saving model ...
# Validation loss decreased (0.003848 --> 0.003842).  Saving model ...
# Validation loss decreased (0.003842 --> 0.003837).  Saving model ...
# Validation loss decreased (0.003837 --> 0.003831).  Saving model ...
# Validation loss decreased (0.003831 --> 0.003826).  Saving model ...
# Validation loss decreased (0.003826 --> 0.003819).  Saving model ...
# Validation loss decreased (0.003819 --> 0.003819).  Saving model ...
# Epoch: 250, Loss: 0.00422
# Validation loss decreased (0.003819 --> 0.003812).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# Epoch: 260, Loss: 0.00491
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# Epoch: 270, Loss: 0.00515
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# Epoch: 280, Loss: 0.00438
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# Epoch: 290, Loss: 0.00436
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# Validation loss decreased (0.003812 --> 0.003811).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003811 --> 0.003810).  Saving model ...
# Epoch: 300, Loss: 0.00418
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.003810 --> 0.003794).  Saving model ...
# Validation loss decreased (0.003794 --> 0.003786).  Saving model ...
# Validation loss decreased (0.003786 --> 0.003773).  Saving model ...
# Validation loss decreased (0.003773 --> 0.003751).  Saving model ...
# Validation loss decreased (0.003751 --> 0.003744).  Saving model ...
# Validation loss decreased (0.003744 --> 0.003730).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Epoch: 310, Loss: 0.00413
# Validation loss decreased (0.003730 --> 0.003713).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003713 --> 0.003710).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003710 --> 0.003709).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# Validation loss decreased (0.003709 --> 0.003707).  Saving model ...
# Validation loss decreased (0.003707 --> 0.003706).  Saving model ...
# Epoch: 320, Loss: 0.00408
# Validation loss decreased (0.003706 --> 0.003698).  Saving model ...
# Validation loss decreased (0.003698 --> 0.003697).  Saving model ...
# Validation loss decreased (0.003697 --> 0.003686).  Saving model ...
# Validation loss decreased (0.003686 --> 0.003682).  Saving model ...
# Validation loss decreased (0.003682 --> 0.003678).  Saving model ...
# Validation loss decreased (0.003678 --> 0.003676).  Saving model ...
# Validation loss decreased (0.003676 --> 0.003671).  Saving model ...
# Validation loss decreased (0.003671 --> 0.003670).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003670 --> 0.003669).  Saving model ...
# Epoch: 330, Loss: 0.00403
# Validation loss decreased (0.003669 --> 0.003668).  Saving model ...
# Validation loss decreased (0.003668 --> 0.003666).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003666 --> 0.003663).  Saving model ...
# Validation loss decreased (0.003663 --> 0.003661).  Saving model ...
# Validation loss decreased (0.003661 --> 0.003656).  Saving model ...
# Validation loss decreased (0.003656 --> 0.003654).  Saving model ...
# Validation loss decreased (0.003654 --> 0.003649).  Saving model ...
# Validation loss decreased (0.003649 --> 0.003646).  Saving model ...
# Validation loss decreased (0.003646 --> 0.003643).  Saving model ...
# Epoch: 340, Loss: 0.00399
# Validation loss decreased (0.003643 --> 0.003641).  Saving model ...
# Validation loss decreased (0.003641 --> 0.003639).  Saving model ...
# Validation loss decreased (0.003639 --> 0.003638).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003638 --> 0.003637).  Saving model ...
# Validation loss decreased (0.003637 --> 0.003637).  Saving model ...
# Validation loss decreased (0.003637 --> 0.003636).  Saving model ...
# Validation loss decreased (0.003636 --> 0.003636).  Saving model ...
# Validation loss decreased (0.003636 --> 0.003633).  Saving model ...
# Validation loss decreased (0.003633 --> 0.003632).  Saving model ...
# Epoch: 350, Loss: 0.00396
# Validation loss decreased (0.003632 --> 0.003630).  Saving model ...
# Validation loss decreased (0.003630 --> 0.003628).  Saving model ...
# Validation loss decreased (0.003628 --> 0.003626).  Saving model ...
# Validation loss decreased (0.003626 --> 0.003624).  Saving model ...
# Validation loss decreased (0.003624 --> 0.003623).  Saving model ...
# Validation loss decreased (0.003623 --> 0.003622).  Saving model ...
# Validation loss decreased (0.003622 --> 0.003621).  Saving model ...
# Validation loss decreased (0.003621 --> 0.003621).  Saving model ...
# Validation loss decreased (0.003621 --> 0.003620).  Saving model ...
# Validation loss decreased (0.003620 --> 0.003620).  Saving model ...
# Epoch: 360, Loss: 0.00393
# Validation loss decreased (0.003620 --> 0.003619).  Saving model ...
# Validation loss decreased (0.003619 --> 0.003618).  Saving model ...
# Validation loss decreased (0.003618 --> 0.003617).  Saving model ...
# Validation loss decreased (0.003617 --> 0.003616).  Saving model ...
# Validation loss decreased (0.003616 --> 0.003615).  Saving model ...
# Validation loss decreased (0.003615 --> 0.003614).  Saving model ...
# Validation loss decreased (0.003614 --> 0.003612).  Saving model ...
# Validation loss decreased (0.003612 --> 0.003612).  Saving model ...
# Validation loss decreased (0.003612 --> 0.003611).  Saving model ...
# Validation loss decreased (0.003611 --> 0.003611).  Saving model ...
# Epoch: 370, Loss: 0.00390
# Validation loss decreased (0.003611 --> 0.003611).  Saving model ...
# Validation loss decreased (0.003611 --> 0.003610).  Saving model ...
# Validation loss decreased (0.003610 --> 0.003610).  Saving model ...
# Validation loss decreased (0.003610 --> 0.003610).  Saving model ...
# Validation loss decreased (0.003610 --> 0.003609).  Saving model ...
# Validation loss decreased (0.003609 --> 0.003609).  Saving model ...
# Validation loss decreased (0.003609 --> 0.003608).  Saving model ...
# Validation loss decreased (0.003608 --> 0.003607).  Saving model ...
# Validation loss decreased (0.003607 --> 0.003607).  Saving model ...
# Validation loss decreased (0.003607 --> 0.003606).  Saving model ...
# Epoch: 380, Loss: 0.00387
# Validation loss decreased (0.003606 --> 0.003606).  Saving model ...
# Validation loss decreased (0.003606 --> 0.003605).  Saving model ...
# Validation loss decreased (0.003605 --> 0.003605).  Saving model ...
# Validation loss decreased (0.003605 --> 0.003605).  Saving model ...
# Validation loss decreased (0.003605 --> 0.003605).  Saving model ...
# Validation loss decreased (0.003605 --> 0.003604).  Saving model ...
# Validation loss decreased (0.003604 --> 0.003604).  Saving model ...
# Validation loss decreased (0.003604 --> 0.003603).  Saving model ...
# Validation loss decreased (0.003603 --> 0.003603).  Saving model ...
# Validation loss decreased (0.003603 --> 0.003602).  Saving model ...
# Epoch: 390, Loss: 0.00385
# Validation loss decreased (0.003602 --> 0.003602).  Saving model ...
# Validation loss decreased (0.003602 --> 0.003601).  Saving model ...
# Validation loss decreased (0.003601 --> 0.003601).  Saving model ...
# Validation loss decreased (0.003601 --> 0.003601).  Saving model ...
# Validation loss decreased (0.003601 --> 0.003600).  Saving model ...
# Validation loss decreased (0.003600 --> 0.003600).  Saving model ...
# Validation loss decreased (0.003600 --> 0.003600).  Saving model ...
# Validation loss decreased (0.003600 --> 0.003599).  Saving model ...
# Validation loss decreased (0.003599 --> 0.003599).  Saving model ...
# Validation loss decreased (0.003599 --> 0.003599).  Saving model ...
# Epoch: 400, Loss: 0.00383
# Validation loss decreased (0.003599 --> 0.003598).  Saving model ...
# Validation loss decreased (0.003598 --> 0.003598).  Saving model ...
# Validation loss decreased (0.003598 --> 0.003597).  Saving model ...
# Validation loss decreased (0.003597 --> 0.003597).  Saving model ...
# Validation loss decreased (0.003597 --> 0.003597).  Saving model ...
# Validation loss decreased (0.003597 --> 0.003596).  Saving model ...
# Validation loss decreased (0.003596 --> 0.003596).  Saving model ...
# Validation loss decreased (0.003596 --> 0.003596).  Saving model ...
# Validation loss decreased (0.003596 --> 0.003596).  Saving model ...
# Validation loss decreased (0.003596 --> 0.003595).  Saving model ...
# Epoch: 410, Loss: 0.00380
# Validation loss decreased (0.003595 --> 0.003595).  Saving model ...
# Validation loss decreased (0.003595 --> 0.003595).  Saving model ...
# Validation loss decreased (0.003595 --> 0.003595).  Saving model ...
# Validation loss decreased (0.003595 --> 0.003594).  Saving model ...
# Validation loss decreased (0.003594 --> 0.003594).  Saving model ...
# Validation loss decreased (0.003594 --> 0.003594).  Saving model ...
# Validation loss decreased (0.003594 --> 0.003593).  Saving model ...
# Validation loss decreased (0.003593 --> 0.003593).  Saving model ...
# Validation loss decreased (0.003593 --> 0.003593).  Saving model ...
# Validation loss decreased (0.003593 --> 0.003593).  Saving model ...
# Epoch: 420, Loss: 0.00378
# Validation loss decreased (0.003593 --> 0.003592).  Saving model ...
# Validation loss decreased (0.003592 --> 0.003592).  Saving model ...
# Validation loss decreased (0.003592 --> 0.003592).  Saving model ...
# Validation loss decreased (0.003592 --> 0.003592).  Saving model ...
# Validation loss decreased (0.003592 --> 0.003592).  Saving model ...
# Validation loss decreased (0.003592 --> 0.003591).  Saving model ...
# Validation loss decreased (0.003591 --> 0.003591).  Saving model ...
# Validation loss decreased (0.003591 --> 0.003591).  Saving model ...
# Validation loss decreased (0.003591 --> 0.003591).  Saving model ...
# Validation loss decreased (0.003591 --> 0.003591).  Saving model ...
# Epoch: 430, Loss: 0.00376
# Validation loss decreased (0.003591 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003590).  Saving model ...
# Validation loss decreased (0.003590 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Epoch: 440, Loss: 0.00374
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003589).  Saving model ...
# Validation loss decreased (0.003589 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Epoch: 450, Loss: 0.00373
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003588).  Saving model ...
# Validation loss decreased (0.003588 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Epoch: 460, Loss: 0.00371
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# EarlyStopping counter: 1 out of 50
# Epoch: 470, Loss: 0.00369
# Validation loss decreased (0.003587 --> 0.003587).  Saving model ...
# EarlyStopping counter: 1 out of 50
# EarlyStopping counter: 2 out of 50
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# EarlyStopping counter: 5 out of 50
# EarlyStopping counter: 6 out of 50
# EarlyStopping counter: 7 out of 50
# EarlyStopping counter: 8 out of 50
# EarlyStopping counter: 9 out of 50
# Epoch: 480, Loss: 0.00397
# EarlyStopping counter: 10 out of 50
# EarlyStopping counter: 11 out of 50
# EarlyStopping counter: 12 out of 50
# EarlyStopping counter: 13 out of 50
# EarlyStopping counter: 14 out of 50
# EarlyStopping counter: 15 out of 50
# EarlyStopping counter: 16 out of 50
# EarlyStopping counter: 17 out of 50
# EarlyStopping counter: 18 out of 50
# EarlyStopping counter: 19 out of 50
# Epoch: 490, Loss: 0.00410
# EarlyStopping counter: 20 out of 50
# EarlyStopping counter: 21 out of 50
# EarlyStopping counter: 22 out of 50
# EarlyStopping counter: 23 out of 50
# EarlyStopping counter: 24 out of 50
# EarlyStopping counter: 25 out of 50
# EarlyStopping counter: 26 out of 50
# EarlyStopping counter: 27 out of 50
# EarlyStopping counter: 28 out of 50
# EarlyStopping counter: 29 out of 50
# Epoch: 500, Loss: 0.00408
# EarlyStopping counter: 30 out of 50
# EarlyStopping counter: 31 out of 50
# EarlyStopping counter: 32 out of 50
# EarlyStopping counter: 33 out of 50
# EarlyStopping counter: 34 out of 50
# EarlyStopping counter: 35 out of 50
# EarlyStopping counter: 36 out of 50
# EarlyStopping counter: 37 out of 50
# EarlyStopping counter: 38 out of 50
# EarlyStopping counter: 39 out of 50
# Epoch: 510, Loss: 0.00399
# EarlyStopping counter: 40 out of 50
# EarlyStopping counter: 41 out of 50
# EarlyStopping counter: 42 out of 50
# EarlyStopping counter: 43 out of 50
# EarlyStopping counter: 44 out of 50
# EarlyStopping counter: 45 out of 50
# EarlyStopping counter: 46 out of 50
# EarlyStopping counter: 47 out of 50
# EarlyStopping counter: 48 out of 50
# EarlyStopping counter: 49 out of 50
# Epoch: 520, Loss: 0.00380
# EarlyStopping counter: 50 out of 50
# Early stopping
# Finished Training

# %%
end = time.time()

# %%
time = end - start
print(f'运行时长为:{int(time)}s')
# Out:
# 运行时长为:471s

# %%
# plot_df(df, x=range(epoch_n), y= lr_list, title='LOSS')

# %%
plot_df(df, x=ep, y= losses, title='LOSS')

# %%
torch.save(model, 'net.pkl')
model2 = torch.load('net.pkl')
# Out:
# D:\Softwore\python38\lib\site-packages\torch\serialization.py:359: UserWarning: Couldn't retrieve source code for container of type lstm. It won't be checked for correctness upon loading.
#   warnings.warn("Couldn't retrieve source code for container of "

# %% [markdown]
# ### 验证测试集

# %%
def rereal(list_temp, min_value, max_value):
    arr = []
    for dat in list_temp:
        temp = dat*(max_value-min_value) + min_value
        arr.append(temp)
    return arr

# %%
outputs = model2(test_X)
loss = criterion(outputs, test_Y)
loss
# Out:
# tensor(0.0032, grad_fn=<MseLossBackward>)

# %%
num = len(test_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = test_Y.detach().numpy().reshape(num)
# # 二维转一维
# y_pred = []
# for i in range(len(y_pred_temp)):
#     y_pred.append(y_pred_temp[i])
# test_Y = test_Y.reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.00315394708097898

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# # 未还原归一化
# plt.figure(figsize=(16,5), dpi=100)
# plt.plot(range(num), y_pred, c='red', lw='1')
# plt.plot(range(num), tru_temp, c='blue', lw='1')

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.15088279582437755

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
from numpy import mean
mean(errors_p)
# Out:
# 9.225686706165899

# %% [markdown]
# ### 验证训练集

# %%
outputs = model2(train_X)
loss = criterion(outputs, train_Y)
loss
# Out:
# tensor(0.0038, grad_fn=<MseLossBackward>)

# %%
num = len(train_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = train_Y.detach().numpy().reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.0037523793432196993

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.1795114097398067

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
mean(errors_p)
# Out:
# 9.645745443386206
