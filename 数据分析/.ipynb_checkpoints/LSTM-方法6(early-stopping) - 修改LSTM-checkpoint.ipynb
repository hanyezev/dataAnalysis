# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn as nn
from torch.nn import init
import torch.nn.functional as F
from torch.utils.data import DataLoader
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from pytorchtools import EarlyStopping

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %% [markdown]
# ### 导入数据

# %%
df2 = pd.read_excel(r"F:\实验室\电网项目\服务器性能数据.xlsx", index_col=0)

# %%
# Draw Plot-----绘图函数
def plot_df(df2, x, y, title="", xlabel='Date_Hour', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df2, x=df2.index, y= df2["主机CPU平均负载"], title='CPU load')

# %% [markdown]
# ### 缺失值填充

# %%
# k近邻法
def knn_mean(ts, n):
    out = np.copy(ts)
    for i, val in enumerate(ts):
        if np.isnan(val):
            n_by_2 = np.ceil(n / 2)
            lower = np.max([0, int(i - n_by_2)])
            upper = np.min([len(ts) + 1, int(i + n_by_2)])
            ts_near = np.concatenate([ts[lower:i], ts[i:upper]])
            out[i] = np.nanmean(ts_near)
    return out
# 使用k-近邻法填补缺失值
df2["主机CPU平均负载"] = knn_mean(df2["主机CPU平均负载"], 24)

# %%
df = df2.copy(deep=True)

# %%
# 滞后阶数
num_hour = 336
data = df["主机CPU平均负载"]
dataframe = pd.DataFrame()
for i in range(num_hour,0,-1):
    dataframe['t-'+str(i)] = data.shift(i)
dataframe['t'] = data.values
dataframe
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 0        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2202  4.5833  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500
# 2203  3.4167  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333
# 2204  2.0833  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833
# 2205  2.1667  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833
# 2206  2.0000  2.1667  2.2500  2.5000  2.2500  2.3333  2.0833  2.0833  2.4167
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 0        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN  2.8333
# 4        NaN  ...     NaN     NaN     NaN     NaN     NaN  2.8333  3.1818
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 2202  2.3333  ...  2.0833  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167
# 2203  2.0833  ...  2.0000  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833
# 2204  2.0833  ...  2.1818  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333
# 2205  2.4167  ...  2.0833  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000
# 2206  2.2500  ...  1.9167  2.0000  1.9167  2.0833  1.8333  2.0000  1.9167
#
#          t-2     t-1       t
# 0        NaN     NaN  2.8333
# 1        NaN  2.8333  3.1818
# 2     2.8333  3.1818  3.0833
# 3     3.1818  3.0833  3.0833
# 4     3.0833  3.0833  2.5000
# ...      ...     ...     ...
# 2202  2.0833  1.8333  2.0000
# 2203  1.8333  2.0000  1.9167
# 2204  2.0000  1.9167  1.7500
# 2205  1.9167  1.7500  2.0000
# 2206  1.7500  2.0000  1.9167
#
# [2207 rows x 337 columns]

# %% [markdown]
# ### 测试集和训练集

# %%
# all_data = dataframe[num_hour:]
# all_data = shuffle(all_data) 
# all_data.to_csv('shuffle.csv')
all_data = pd.read_csv(r"C:\Code\Python\PycharmProjects\数据分析\数据分析\shuffle.csv",index_col=0)
all_data
# Out:
#        t-336   t-335   t-334   t-333   t-332   t-331   t-330   t-329   t-328  \
# 510   3.9167  3.5833  3.5000  3.7500  3.8333  3.5833  3.8182  4.0000  4.4167
# 854   3.7500  3.7500  4.5000  3.9167  3.8182  3.9167  4.3333  3.4167  3.4167
# 1720  3.3333  2.5833  2.7500  2.5000  2.1667  2.0000  2.2500  2.0000  1.9091
# 1564  4.0000  4.1667  5.0833  4.5000  5.9091  7.2500  6.6667  6.7500  4.6667
# 526   3.6667  3.5833  3.2500  3.8182  3.6667  4.1667  3.3636  3.5000  3.9167
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.8333  2.3333  2.1667  2.0833  2.0833  2.5000  2.7500  2.3333  3.0833
# 2055  3.9167  3.8333  3.8333  3.0000  3.0833  3.0833  3.0000  3.0000  3.0000
# 1356  3.5000  3.5000  4.5000  3.9167  4.2500  4.1667  3.8333  3.9091  3.7500
# 2045  4.4167  4.5833  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1190  4.7500  4.3333  4.0833  2.9167  3.1667  3.1667  2.4167  2.2727  2.1667
#
#        t-327  ...     t-9     t-8     t-7     t-6     t-5     t-4     t-3  \
# 510   3.7500  ...  3.6000  3.5833  3.2500  3.3333  3.7500  3.4167  3.7500
# 854   3.6667  ...  2.3333  2.5833  2.3636  3.5833  3.9167  5.2500  5.6667
# 1720  2.2500  ...  4.5000  4.1667  4.3333  3.5833  3.5000  2.3333  2.9167
# 1564  5.5833  ...  2.5000  2.4167  2.1667  2.5833  2.1667  2.3333  2.9167
# 526   3.8333  ...  3.9167  3.7500  3.7500  4.5000  3.9167  3.8182  3.9167
# ...      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 1873  2.0833  ...  4.4167  4.4167  4.5833  3.4167  2.0833  2.1667  2.0000
# 2055  2.7500  ...  2.5833  2.7500  2.6667  2.5833  2.5833  2.5000  2.5000
# 1356  3.5000  ...  2.3636  2.2500  2.3333  2.7500  2.5000  2.7500  3.6667
# 2045  3.6667  ...  2.3333  2.7500  2.0833  2.6667  3.0833  3.2500  2.8333
# 1190  2.2500  ...  3.5000  3.8333  3.5000  4.0000  6.0833  5.1818  5.3333
#
#          t-2     t-1       t
# 510   3.1667  3.1667  3.4167
# 854   4.2500  5.3333  4.7500
# 1720  3.6667  3.9167  3.8333
# 1564  2.2500  2.3333  2.0833
# 526   4.3333  3.4167  3.4167
# ...      ...     ...     ...
# 1873  2.1667  2.2500  2.5000
# 2055  2.1667  2.7500  2.1667
# 1356  3.6667  3.2500  2.9167
# 2045  2.1667  2.3333  2.5833
# 1190  3.9167  3.4545  4.2500
#
# [1871 rows x 337 columns]

# %%
var1 = int(len(all_data)*0.6)
var2 = int(len(all_data)*0.8)
train_data = all_data[0:var1]
validate_data = all_data[var1:var2]
test_data = all_data[var2:]
# train_data
# test_data
# validate_data

# %%
max_value = max(train_data.max().values)
min_value = min(train_data.min().values)
ch = max_value - min_value

# %% [markdown]
# ### 归一化

# %%
train_data_normalized = scaler.fit_transform(train_data.values.reshape(-1, 1))
train_data_normalized = train_data_normalized.reshape(-1,num_hour+1)
train_data_normalized.shape
# Out:
# (1122, 337)

# %%
validate_data_normalized = scaler.transform(validate_data.values.reshape(-1, 1))
validate_data_normalized = validate_data_normalized.reshape(-1,num_hour+1)
validate_data_normalized.shape
# Out:
# (374, 337)

# %%
test_data_normalized = scaler.transform(test_data.values.reshape(-1, 1))
test_data_normalized = test_data_normalized.reshape(-1,num_hour+1)
test_data_normalized.shape
# Out:
# (375, 337)

# %%
train_X = torch.Tensor(train_data_normalized[:,0:-1].reshape(-1, 1, 336))
train_Y = torch.Tensor(train_data_normalized[:,-1].reshape(-1, 1, 1))
train_Y.shape
# Out:
# torch.Size([1122, 1, 1])

# %%
validate_X = torch.Tensor(validate_data_normalized[:,0:-1].reshape(-1, 1, 336))
validate_Y = torch.Tensor(validate_data_normalized[:,-1].reshape(-1, 1, 1))
validate_X.shape
# Out:
# torch.Size([374, 1, 336])

# %%
test_X = torch.Tensor(test_data_normalized[:,0:-1].reshape(-1, 1, 336))
test_Y = torch.Tensor(test_data_normalized[:,-1].reshape(-1, 1, 1))
test_X.shape
# Out:
# torch.Size([375, 1, 336])

# %%
# train_data_temp = torch.utils.data.TensorDataset(train_X, train_Y)
# test_data_temp = torch.utils.data.TensorDataset(test_X, test_Y)
# train_data = DataLoader(train_data_temp, batch_size=256, shuffle=True, num_workers=1)#训练数据
# test_data = DataLoader(test_data_temp, batch_size=256, shuffle=False, num_workers=2)#测试数据

# %%
start = time.time()

# %% [markdown]
# ### 建立LSTM模型

# %%
class lstm(nn.Module):
    def __init__(self,input_size=16,hidden_size=100,output_size=1,num_layer=2):
        super(lstm,self).__init__()
        self.layer1 = nn.LSTM(input_size,hidden_size,num_layer)
        self.layer2 = nn.Linear(hidden_size,output_size)
    
    def forward(self,x):
        x,_ = self.layer1(x)
        s, b, h = x.size()
        x = x.reshape(s*b,h)
        x = self.layer2(x)
        x = x.reshape(s, b, -1)
        return x

model = lstm(336, 256, 1, 2)
model
# Out:
# lstm(
#   (layer1): LSTM(336, 256, num_layers=2)
#   (layer2): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
epoch_n = 1000
# 初始化 early_stopping 对象
# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
patience = 20  

# 关于 EarlyStopping 的代码可先看博客后面的内容
early_stopping = EarlyStopping(patience, verbose=True)

# %%
# 开始训练
ep=[]
losses = []
lr_list = []
for e in range(1, epoch_n+1):
    var_x = Variable(train_X)
    var_y = Variable(train_Y)
    # 前向传播
    out = model(var_x)
    loss = criterion(out, var_y)
    # 反向传播
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if e % 10 == 0: # 每 10 次输出结果
        print('Epoch: {}, Loss: {:.5f}'.format(e, loss.item()))
    ep.append(e)
    losses.append(loss.item())
    
    valid_output = model(validate_X)
    valid_loss = criterion(valid_output, validate_Y)
    
    early_stopping(valid_loss, model)
    
    # 若满足 early stopping 要求
    if early_stopping.early_stop:
        print("Early stopping")
        # 结束模型训练
        break
    
#     break
#     if (e+1)%120 == 0:
#         for p in optimizer.param_groups:
#             p['lr'] *= 0.1
#     lr_list.append(optimizer.state_dict()['param_groups'][0]['lr'])

print('Finished Training')
# Out:
# Validation loss decreased (inf --> 27.908661).  Saving model ...
# Validation loss decreased (27.908661 --> 0.041007).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# Validation loss decreased (0.041007 --> 0.027060).  Saving model ...
# Validation loss decreased (0.027060 --> 0.020610).  Saving model ...
# Epoch: 10, Loss: 0.02297
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# Epoch: 20, Loss: 0.02437
# EarlyStopping counter: 11 out of 20
# EarlyStopping counter: 12 out of 20
# EarlyStopping counter: 13 out of 20
# EarlyStopping counter: 14 out of 20
# EarlyStopping counter: 15 out of 20
# EarlyStopping counter: 16 out of 20
# EarlyStopping counter: 17 out of 20
# Validation loss decreased (0.020610 --> 0.020361).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Epoch: 30, Loss: 0.02351
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.020361 --> 0.019943).  Saving model ...
# Validation loss decreased (0.019943 --> 0.019458).  Saving model ...
# Validation loss decreased (0.019458 --> 0.019221).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.019221 --> 0.018922).  Saving model ...
# Validation loss decreased (0.018922 --> 0.018228).  Saving model ...
# Validation loss decreased (0.018228 --> 0.017418).  Saving model ...
# Epoch: 40, Loss: 0.01972
# Validation loss decreased (0.017418 --> 0.016805).  Saving model ...
# Validation loss decreased (0.016805 --> 0.016394).  Saving model ...
# Validation loss decreased (0.016394 --> 0.015903).  Saving model ...
# Validation loss decreased (0.015903 --> 0.015152).  Saving model ...
# Validation loss decreased (0.015152 --> 0.014366).  Saving model ...
# Validation loss decreased (0.014366 --> 0.013982).  Saving model ...
# Validation loss decreased (0.013982 --> 0.013722).  Saving model ...
# Validation loss decreased (0.013722 --> 0.012726).  Saving model ...
# Validation loss decreased (0.012726 --> 0.011795).  Saving model ...
# Validation loss decreased (0.011795 --> 0.011417).  Saving model ...
# Epoch: 50, Loss: 0.01357
# Validation loss decreased (0.011417 --> 0.010886).  Saving model ...
# Validation loss decreased (0.010886 --> 0.010655).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.010655 --> 0.010085).  Saving model ...
# Validation loss decreased (0.010085 --> 0.010017).  Saving model ...
# Validation loss decreased (0.010017 --> 0.009766).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.009766 --> 0.009706).  Saving model ...
# Validation loss decreased (0.009706 --> 0.009224).  Saving model ...
# Validation loss decreased (0.009224 --> 0.009046).  Saving model ...
# Epoch: 60, Loss: 0.01088
# Validation loss decreased (0.009046 --> 0.008904).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.008904 --> 0.008571).  Saving model ...
# Validation loss decreased (0.008571 --> 0.008416).  Saving model ...
# Validation loss decreased (0.008416 --> 0.008297).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.008297 --> 0.008293).  Saving model ...
# Validation loss decreased (0.008293 --> 0.007965).  Saving model ...
# Validation loss decreased (0.007965 --> 0.007804).  Saving model ...
# Validation loss decreased (0.007804 --> 0.007677).  Saving model ...
# Epoch: 70, Loss: 0.00898
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.007677 --> 0.007538).  Saving model ...
# Validation loss decreased (0.007538 --> 0.007261).  Saving model ...
# Validation loss decreased (0.007261 --> 0.007116).  Saving model ...
# Validation loss decreased (0.007116 --> 0.007049).  Saving model ...
# Validation loss decreased (0.007049 --> 0.007036).  Saving model ...
# Validation loss decreased (0.007036 --> 0.006787).  Saving model ...
# Validation loss decreased (0.006787 --> 0.006605).  Saving model ...
# Validation loss decreased (0.006605 --> 0.006518).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 80, Loss: 0.00745
# Validation loss decreased (0.006518 --> 0.006324).  Saving model ...
# Validation loss decreased (0.006324 --> 0.006181).  Saving model ...
# Validation loss decreased (0.006181 --> 0.006156).  Saving model ...
# Validation loss decreased (0.006156 --> 0.006149).  Saving model ...
# Validation loss decreased (0.006149 --> 0.005975).  Saving model ...
# Validation loss decreased (0.005975 --> 0.005935).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005935 --> 0.005826).  Saving model ...
# Validation loss decreased (0.005826 --> 0.005808).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 90, Loss: 0.00639
# Validation loss decreased (0.005808 --> 0.005690).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005690 --> 0.005689).  Saving model ...
# Validation loss decreased (0.005689 --> 0.005579).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005579 --> 0.005535).  Saving model ...
# Validation loss decreased (0.005535 --> 0.005526).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005526 --> 0.005436).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 100, Loss: 0.00560
# Validation loss decreased (0.005436 --> 0.005376).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005376 --> 0.005318).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005318 --> 0.005243).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005243 --> 0.005217).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# Epoch: 110, Loss: 0.00664
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.005217 --> 0.005057).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# Epoch: 120, Loss: 0.00490
# EarlyStopping counter: 9 out of 20
# Validation loss decreased (0.005057 --> 0.005001).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.005001 --> 0.004968).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.004968 --> 0.004967).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 130, Loss: 0.00457
# Validation loss decreased (0.004967 --> 0.004881).  Saving model ...
# Validation loss decreased (0.004881 --> 0.004826).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004826 --> 0.004808).  Saving model ...
# Validation loss decreased (0.004808 --> 0.004780).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004780 --> 0.004774).  Saving model ...
# Validation loss decreased (0.004774 --> 0.004762).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Epoch: 140, Loss: 0.00421
# Validation loss decreased (0.004762 --> 0.004760).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# Validation loss decreased (0.004760 --> 0.004748).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 150, Loss: 0.00395
# Validation loss decreased (0.004748 --> 0.004709).  Saving model ...
# Validation loss decreased (0.004709 --> 0.004683).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004683 --> 0.004676).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Validation loss decreased (0.004676 --> 0.004634).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# Validation loss decreased (0.004634 --> 0.004605).  Saving model ...
# EarlyStopping counter: 1 out of 20
# Epoch: 160, Loss: 0.00377
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# EarlyStopping counter: 11 out of 20
# Epoch: 170, Loss: 0.00352
# EarlyStopping counter: 12 out of 20
# Validation loss decreased (0.004605 --> 0.004575).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# Validation loss decreased (0.004575 --> 0.004551).  Saving model ...
# Epoch: 180, Loss: 0.00337
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# Validation loss decreased (0.004551 --> 0.004547).  Saving model ...
# EarlyStopping counter: 1 out of 20
# EarlyStopping counter: 2 out of 20
# EarlyStopping counter: 3 out of 20
# EarlyStopping counter: 4 out of 20
# EarlyStopping counter: 5 out of 20
# Epoch: 190, Loss: 0.00461
# EarlyStopping counter: 6 out of 20
# EarlyStopping counter: 7 out of 20
# EarlyStopping counter: 8 out of 20
# EarlyStopping counter: 9 out of 20
# EarlyStopping counter: 10 out of 20
# EarlyStopping counter: 11 out of 20
# EarlyStopping counter: 12 out of 20
# EarlyStopping counter: 13 out of 20
# EarlyStopping counter: 14 out of 20
# EarlyStopping counter: 15 out of 20
# Epoch: 200, Loss: 0.00371
# EarlyStopping counter: 16 out of 20
# EarlyStopping counter: 17 out of 20
# EarlyStopping counter: 18 out of 20
# EarlyStopping counter: 19 out of 20
# EarlyStopping counter: 20 out of 20
# Early stopping
# Finished Training

# %%
end = time.time()

# %%
time = end - start
print(f'运行时长为:{int(time)}s')
# Out:
# 运行时长为:916s

# %%
# plot_df(df, x=range(epoch_n), y= lr_list, title='LOSS')

# %%
plot_df(df, x=ep, y= losses, title='LOSS')

# %%
torch.save(model, 'net.pkl')
model2 = torch.load('net.pkl')
# Out:
# D:\Softwore\python38\lib\site-packages\torch\serialization.py:359: UserWarning: Couldn't retrieve source code for container of type lstm. It won't be checked for correctness upon loading.
#   warnings.warn("Couldn't retrieve source code for container of "

# %% [markdown]
# ### 验证测试集

# %%
def rereal(list_temp, min_value, max_value):
    arr = []
    for dat in list_temp:
        temp = dat*(max_value-min_value) + min_value
        arr.append(temp)
    return arr

# %%
outputs = model2(test_X)
loss = criterion(outputs, test_Y)
loss
# Out:
# tensor(0.0045, grad_fn=<MseLossBackward>)

# %%
num = len(test_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = test_Y.detach().numpy().reshape(num)
# # 二维转一维
# y_pred = []
# for i in range(len(y_pred_temp)):
#     y_pred.append(y_pred_temp[i])
# test_Y = test_Y.reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.004542239106424508

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# # 未还原归一化
# plt.figure(figsize=(16,5), dpi=100)
# plt.plot(range(num), y_pred, c='red', lw='1')
# plt.plot(range(num), tru_temp, c='blue', lw='1')

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.2172977914011633

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
from numpy import mean
mean(errors_p)
# Out:
# 12.158233137948487

# %% [markdown]
# ### 验证训练集

# %%
outputs = model2(train_X)
loss = criterion(outputs, train_Y)
loss
# Out:
# tensor(0.0035, grad_fn=<MseLossBackward>)

# %%
num = len(train_Y)

# %%
outputs = outputs.reshape(num)
y_pred_temp = outputs.detach().numpy()
tru_temp = train_Y.detach().numpy().reshape(num)

# %%
MSE = 0
for i in range(num):
    MSE += (y_pred_temp[i] - tru_temp[i])**2
MSE /= num
MSE
# Out:
# 0.003504524143061713

# %%
predict = rereal(y_pred_temp,min_value,max_value)
truth =  rereal(tru_temp,min_value,max_value)

# %%
# 还原归一化
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), predict, c='red', lw='1')
plt.plot(range(num), truth, c='blue', lw='1')

# %%
# 求真实值与预测值的MSE
MSE = 0
for i in range(num):
    MSE += (predict[i] - truth[i])**2
MSE /= num
MSE
# Out:
# 0.16765417665700205

# %%
# 求真实值与预测值的误差值
errors = []
for i in range(num):
    error = abs(truth[i] - predict[i])
    errors.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors, c='black', lw='1')
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
# 求真实值与预测值的误差值占原真实值的百分比
errors_p = []
for i in range(num):
    error = ((abs(truth[i] - predict[i]))/truth[i])*100
    errors_p.append(error)
plt.figure(figsize=(16,5), dpi=100)
plt.plot(range(num), errors_p, c='black', lw='1')
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %%
mean(errors_p)
# Out:
# 10.436783297583249
